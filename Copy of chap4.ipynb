# %%
#@title Copyright 2024 Diarra Yacouba (Diarray). Double-click for license information.
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# ## Intro final chapter!
# Bienvenue dans ce dernier grand chapitre de votre formation Mr sanogo! <br/>
# **By the way** ceci est aussi le dernier notebook d'introduction que j'écrirai, en d'autres termes **c'est maintenant qu'on va commencer à s'amuser 😂**. Pour ce dernier grand chapitre on va surtout parler **d'affichage formatée, de documentation et essayer de naviger le vaste monde de python**. Ce chapitre
# à pour but de vous habituer à des syntax et des pratiques/conventions largement utiliser par les pythonistas pour que vous puissiez explorer ce nouveau monde de manière plus fluide. Sans plus tarder **let's get started**

# %% [markdown]
# ## Affichage formaté!
# On commence par une première notion très largement repandue, comment obtenir perfomer le meilleur en terme d'affichage en python! On l'a vue la méthode print est la méthode standard de sortie en python, mais en réalité on peut bien plus que **print(x)**. Il arrive souvent qu'on ait besoin d'afficher un message d'une manière particulière comme incorporer des infos variables à un message par défaut, il y'a plusieurs manière de faire ce genre d'affichage des méthodes dérivées des autres langages basée sur la syntax avec **l'operateur (%)** aux **formatted strings**. On va voir certains de ces méthodes des moins populaires aux plus populaire!

# %% [markdown]
# ## Pseudo formattage en utilisant les propriétés des strs et de la fonction print!
# Avant de parler des méthodes de formattage en elles même, parlons de quelques syntaxs qu'on a déjà vu ici mais qu'on ne peut pas rééllement considérer comme du formattage! Par exemple sachant qu'on peut utiliser l'operateur "+" pour concatener deux strs on peut utiliser cela pour intégrer des strings entre eux au moment de l'affichage, on peut aussi modifier les propriétés d'un afficage en modifiant la valeur des arguments de la fonctions print!

# %%
num = 666
name = "Abdou"
solde = 12345789.0
# Par défaut l'argument sep de la fonction print va permettre d'afficher ces arguments séparés par des espaces
# Il est important de noter que pour la fonction print, chaque valeur affichée ici est un argument positionnel à part
print("Compte numéro:", num, "; propriétaire:", name, "; solde:", solde)
# On peut également utiliser '+' pour concatener les strings comme dit précédemment
# Cette voici du point de vue de la fonction il n'y a plus qu'un seul argument
print("Compte numéro: " + str(num) + "; propriétaire: " + name + "; solde: " + str(solde))
# Out:
# Compte numéro: 666 ; propriétaire: Abdou ; solde: 12345789.0
# Compte numéro: 666; propriétaire: Abdou; solde: 12345789.0

# %% [markdown]
# ## Affichage formatée avec l'opérateur "%"
# Une méthode rélativement peu utilisé depuis Python3 mais plutôt populaire avant et considéré comme la seule méthode d'affichage formatée dans d'autres langages comme le C par exemple, on peut utiliser l'opérateur "%" suivi d'un suffix variables en fonctions du type de l'objet qu'on souhaite afficher pour intégrer des ints (%d), floats (%f) et strs (%s)

# %%
print("Compte numéro: %d"%num)
formatting = (num, name, solde)
print("Compte numéro: %d; propriétaire: %s; solde: %.1f" %formatting)
# C'est le rôle de l'opérateur % losrqu'il est de cette manière avec les strings
# Notez qu'il est important d'avoir les abstractions "%x" dans le string à formater
# On peut même les utiliser comme opérateur de convertions
convert = "Compte numéro: %f" %num
print(convert)
# Disons que je veux limiter cet affichage deux chiffres après la virgule
print("Compte numéro %.1f" %num)
# Out:
# Compte numéro: 666
# Compte numéro: 666; propriétaire: Abdou; solde: 12345789.0
# Compte numéro: 666.000000
# Compte numéro 666.0

# %% [markdown]
# ## Strings methods!
# Les strs eux même en python fournissent des methodes pour faire de l'affichage formatée, jettons un petit coup d'oeil aux methodes **format, center, ljust and rjust**!
# La méthode **format** fournit un autre moyen d'intégrer des objets de différents type dans un string, les autres permettent d'ajuster la position d'un message par rapport à un prompt!

# %%
print("Compte numéro: {}; propriétaire: {}; solde: {}".format(num, name, solde))
# On peut configurer un systems de clés pour cette méthode
print("Compte numéro: {key1}; propriétaire: {key}; solde: {key0}".format(key0=solde, key1=num, key=name))
# Positionner un message proportionnellement à un prompt
message = "Abdou"
print(message.center(11, "$"))
print(message.ljust(10, "$"))
print(message.rjust(10, "$"))
# Out:
# Compte numéro: 666; propriétaire: Abdou; solde: 12345789.0
# Compte numéro: 666; propriétaire: Abdou; solde: 12345789.0
# $$$Abdou$$$
# Abdou$$$$$
# $$$$$Abdou

# %% [markdown]
# ## Formatted strings!
# Les **F-strings ou String formatées** sont un type de str permattant de rendre la syntax des méthode comme format, center et etc plus concise et compréhensible, disponible depuis la version 3.6 de python, cette méthode est largement devenu la plus populaire dès lors grâce à sa syntax plus naturelle pour les débutants!<br/>
# Pour créer un formatted string (string formattées) il suffit de le prefixer du caratère "f". Notez que les strings formattées ne sont pas un nouveau type de données, ce sont aussi des str!

# %%
fstr = f"Compte numéro: {num + 12}; propriétaire: {name}; solde: {solde}"
print(fstr)
#ljust()
print(f"{'$'*10}{message}")
#rjust
print(f"{message}{'$'*10}")
# center
print(f"{'$'*10}{message}{'$'*10}")
# Out:
# Compte numéro: 678; propriétaire: Abdou; solde: 12345789.0
# $$$$$$$$$$Abdou
# Abdou$$$$$$$$$$
# $$$$$$$$$$Abdou$$$$$$$$$$

# %% [markdown]
# ## Documentations and doc strings!
# Maintenant on va parler d'un autre aspect plutôt important niveau projet notament par rapport aux fonctions et aux classes qu'on écrit. Une documentation est essentielle pour qu'une personne extérieur puisse comprendre votre projet et votre code et puisse donc l'executer et/ou le modifier sans trop de peine, la documentation est l'âme du Open Source. Ainsi il est important de documenter tout projet sur lequel vous travaillerez même si ce dernier n'est pas open source car des personnes peuvent intégrer l'équipe et être amener à éditer ou à maintenir vos codes. Donc il faut se familiariser avec les notions de **README file, MARKDOWN** et de savoir comment rédiger une documentation cohérente de facilement compréhensible pour vos projets. Aussi votre premier reflexe quand vous voulez commencer avec un projet, framework ou outil open source doit être de checker la documentation! **C'est pour cela qu'il est rééllement conseillé de se mettre à l'aise avec l'anglais**<br/>
# Mais bon ça c'est pour les documentations externes au code car oui il est possible de documenter à l'interieur du code lui même grâce aux **Docs strings**, différents des commentaires qui servent souvent de à orienter l'auteur des codes lui même les docs strings sont une légère variation des strings pouvent être écrits sur plusieurs lignes qui nous permettent d'expliquer le fonctionnement ou le rôle d'une fonction ou d'une classe aux futurs utilisateurs de cette dernière.

# %%
"""Ceci est un doc string, notez que toutes les méthodes normalement applicables aux strings lui sont aussi applicable
à l'interieur vous pouvez apportez des détails à vos classes et fonctions tels que:
Le type des arguments, les arguments optionnelles avec leur valeur par défaut
le travail effectuer par la fonction et même détaillé comment ce travail"""
# Out:
# "Ceci est un doc string, notez que toutes les méthodes normalement applicables aux strings lui sont aussi applicable\nà l'interieur vous pouvez apportez des détails à vos classes et fonctions tels que:\nLe type des arguments, les arguments optionnelles avec leur valeur par défaut\nle travail effectuer par la fonction et même détaillé comment ce travail"

# %%
def is_pair(nombre: int | float) -> bool: # Depuis la version 3.10 de python cette syntax peut être utilisé pour préciser le type d'une variable quand cette dernière peut en avoir plusieurs
  """Ceci est la nouvelle documentation de la fonction is_pair.
  Il s'agit d'une fonction qui peut nous dire si oui ou non un nombre donné est paire
  Elle a un seul argument 'nombre' de type int ou float et retourne un booléen
  Args:
  nombre (int | float): N'importe quel nombre réélle

  Return: -> bool"""
  if nombre % 2:
    # si nombre % 2 est différent de zéro cette condition sera vrai et donc on pourra en conclure que le nombre est impaire
    return False
  return True # Si le block précédent est executé celle ci ne le sera pas, donc pas vraiment besoin de faire un "else"

# %%
is_pair(87) # Vous pouvez remarqué la nouvelle documentation
# Out:
# False

# %% [markdown]
# ## Python's Ecosystem!
# Maintenant qu'on peut dire avoir officiellement finis avec l'introduction à python, prenons une minute pour observer ce qu'il y a autour de nous maintenant qu'on est en mésure de comprendre ce que c'est. **Pourquoi python?** Vous l'aurez compris python est un langage de haut-niveau à but générale, Chouchou d'une grande partie des domaines surtout ceux qui ne sont pas basée que sur la programmation python nous permet de travailler dans tellement de domaines qu'il s'est crée un ecosystem diverse et varié pour tellement de tâche différente, entre [socket](https://docs.python.org/3/library/socket.html) pour **la programmation réseau**, [numpy](https://numpy.org/) pour **l'algèbre linéaire**, [pandas](https://pandas.pydata.org/docs/) pour **la science des données**, [scikit-learn](https://scikit-learn.org/) pour **le machine learning**, [django](https://www.djangoproject.com/) pour **le developpement web**, [rospy](https://wiki.ros.org/rospy) pour **la robotique**, [scapy](https://scapy.net/) pour **la manipulation des paquets réseaux très largement utilisé par les professionnels de cybersecutité** et tellement d'autres **frameworks et librairies** aussi impressionants que diverse!<br/>
# De part sa simplicité python s'est aussi construit une communauté extraordinaire et supportive, les pythonistas comme ils s'appelent sont partout dans tous les domaines et ils crée des plateformes et forums comme le [forum officiel de python](https://discuss.python.org/) où vous pouvez à tout moment trouver de l'aide avec un code python mais aussi des communautés plus spécifiques comme [real python](https://realpython.com), [kaggle](https://kaggle.com) pour le machine learnng et la science des données, [pypi](https://pypi.org/) où les pythonistas se partagent des packages et module qu'ils ont eux même créer. L'ecosystème python est immense du à sa grande flexibilité!<br/>
# **Ce que vous pourrez accomplir avec python ne dépends que de votre motivation**, maintenant que vous y êtes préparer, je vais vous laissez naviguer ce nouveau monde pendant les prochaines sessions!<br/>
# ***Keep Learning***

# %% [markdown]
# ## Homework!
# Ecrire et documenter un module python pour le traitement de textes, le module doit contenir au moins trois functions, une permettant de néttoyer un texte pour lui enlever toute ponctuation, une permettant d'associer à chaque mot d'un texte un identifiant numérique unique (token) et retourne la liste de tokens correspondant à un text donné (attention les tokens créés devront être persister afin d'avoir à chaque fois le même token pour un mot qui a déjà été tokeniser par la fonction) et une fonction permettant d'identifier la langue d'un texte donné en fonctions des caractères qui composent le texte (La fonction doit avoir un nombre finie de langages connues et retourner le message approprié si le texte ne correspond à aucune des langues qu'elle connaît).<br/>
# **Vous êtes libre de rajouter autant de fonctions que vous voulez!**
# Assurez vous que chaque fonction dispose d'une signature complète et explicite et d'un moyen d'asserter la cohérence des types de données qui lui sont passées en paramètres.

# %%
import string
def supprime_ponctuation(texte):
    texte.translate(str.maketrans("", "", string.ponctuation))
    return texte.translate(str.maketrans("", "", string.ponctuation))
def tokenize (texte):
  return texte.split(" ")
def langdetect (texte):
  lang = detect(texte)
  print (lang)
