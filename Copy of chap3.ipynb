# %%
#@title Copyright 2023 Diarra Yacouba (Diarray). Double-click for license information.
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# ## Intro!
# **Welcome back for chapter 3!**<br/>
# Bienvenue pour ce **troisième et dernier grand chapitre** de votre initiation à python Mr Sanogo. Dans ce chapitre on va parler de **fonctions, d'arguments, de signature de fonction, de mapping, de callable, de generateur, de module, de variable locale et globale et de tracebacks**. Après ce chapitre vous allez beaucoup coder car j'estime que après celui là on aura fait l'initiation et que vous saurez désormais ce qu'il faut pour coder des mini projets excitants. Sans plus tarder **Let's get started** 😀

# %% [markdown]
# ## Les fonctions en programmation!
# Connaître les fonctions et savoir comment les écrires est un skill phare que tout bon programmer se doit d'avoir. Elles sont la base pour pouvoir écrire des **codes adaptifs et réutilisables**. Donc pour commencer essayons d'apporter une définition à ce nouveau concept. **C'est quoi une fonction donc?**<br/>
# Et bien une fonction, ce n'est rien de plus qu'un bout de code permettant de faire une tâche specifique. Ce qui rend les fonctions si utiles c'est qu'une fois qu'on l'a defini on peut juste l'appeler autant de fois qu'on veut dans un programme sans avoir à reécrire le code de la fonction, **c'est ça la réutilisabilité**.<br/>
# Une fonction peut avoir **des arguments** tout comme elle peut ne pas en avoir. Les arguments pour une fonction sont des entrées, des données avec ou sur lesquelles elle peut travailler et qu'on peut utiliser pour modifier son comportement. C'est ça **l'adaptabilité**. Les arguments d'une fonction peuvent aussi voir des **valeurs par défaut**, cela permet à la fonction de pouvoir anticiper **les cas d'utilisation dis clasiques**.<br/>
# Vous l'aurez compris **les fonctions c'est la vie!** Et d'ailleurs la premère ligne de code qu'on a executé ici était elle même un appel à une fonction. Python possède une panoplie de **fonction built-in**, c'est-à-dire des fonctions qui ont déjà été écrite par les développeurs du langage et qu'on peut donc utiliser sans avoir à les rédefinir.<br/>
# Vous vous en doutez surêment parmis les fonctions built-in on a les fonctions **print et input** que que l'on utilise depuis le premier notebook, mais aussi beaucoup d'autres comme **max, sorted, abs, all, any, pow, bin etc...** <br/>
# Pour appeler une fonction il suffit d'écrire son nom suivi des parenthèses et entre les parathèses on mettra nos arguments si nécéssaire. On peut mettre les arguments dans l'ordre qu'ils sont dans la définition de la fonction ou en précisant explicitement quel valeur correspont à quel argument! **Let's check this out!**

# %%
print("Hello world") # Affichera hello world
print("Hello world", "Bonjour le monde", "hi") # Affichera Hello world et Bonjour le monde. On dit que la fonction print accepte des arguments positionnels
# Out:
# Hello world
# Hello world Bonjour le monde hi

# %%
# Affichera Hello worldSEPARATORBonjour le monde, on dit que la fonction acceptes des arguments par mots clés (Keyword args)
# "sep" est le nom de l'argument qui sépare les objets afficher par la fonction print, sa valeur par défaut est l'espace
print("Hello world", "Bonjour le monde", "hi",  sep=" v ")
# Out:
# Hello world v Bonjour le monde v hi

# %%
# Affichera Hello world Bonjour le mondeEND, end est un autre argument de mot clés
# end est l'argument qui détermine ce que la fonction print va afficher après tout ses arguments positionnels. Par défaut le caractère "\n" qui permet d'aller à la ligne suivante
print("Hello world", "Bonjour le monde", "hi", end="\n")
print("Hello world", "Bonjour le monde", "hi")
# Out:
# Hello world Bonjour le monde hi
# Hello world Bonjour le monde hi

# %%
# Va juste allez à la ligne suivante, on dit que la fonction print n'a pas d'arguments obligatoires
# Ce qui veut dire que tous ses argument ont une valeur par défaut, si on ne lui donne pas d'argument elle va juste afficher "\n"
print()

# %%
# Va afficher None, on dit que la fonction print ne fait pas de retour.
# Elle ne retourne rien ou que son type de retour est None
print(print())
# Out:
# None

# %%
# On dit que la fonction input n'a pas d'arguments obligatoire
input("Donnez moi un nombre entre 0 et 100: ") # Affichera un message, un prompt avant de recupérer son entrée
input() # Recupera son entrée sans affficher de message
# Out:
# Donnez moi un nombre entre 0 et 100:
# ''

# %%
# On dit que la fonction input a pour type de retour "str"
print(input("Donnez moi un nombre entre 0 et 100: ")) # Affichera le nombre recupérer par la fonction input
var = input()
print(type(var))
# Out:
# Donnez moi un nombre entre 0 et 100:
#
#
# <class 'str'>

# %%
var = print()
print(var)
# Out:
# None

# %%
# Retournera une erreur, on dit que la fonction sorted a besoin d'un argument au moins pour fonctionner
sorted()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-7c29ebb4f9e4> in <cell line: 2>()
#       1 # Retournera une erreur, on dit que la fonction sorted a besoin d'un argument au moins pour fonctionner
# ----> 2 sorted()
#
# TypeError: sorted expected 1 argument, got 0

# %%
# Affichera une liste avec les éléments de ce tuple triés.
# On dit que le type de retour de la fonction sorted est "list" et qu'il prend un argument de type iterable
tup = {1, -7, 2, 45, 21, 15, -77, 0}
print(sorted(tup), type(sorted(tup)))

# %%
# Affichera la liste triée de façon décroissante
# On dit que la fonction sorted possède un argument optionnel "reverse" qui permet de renverser la liste trié
print(sorted(tup, reverse=True))

# %%
# On dit que la fonction max peut prendre plusieurs arguments positionnel comme print ou bien un iterable
print(max(1, -4, 10, 7))
print(max(tup))

# %%
# On dit que le callable bin prend une seule entrée de type "int"
# Et a pour type de retour un str representant le nombre en binaire. On reviendra sur la notion de callable plus tard
binaire = bin(10) # Va convertir le nombre en binaire
print(binaire, type(binaire))
# Out:
# 0b1010 <class 'str'>

# %% [markdown]
# ## Comment écrire sa propre fonction?
# Les notion précédente peuvent être générailiser. **C'est à dire qu'une fonction peut ne pas avoir d'arguments, tout comme elle peut en avoir un infinité. Si elle a des arguments alors ceux ci ont des types, si elle retourne quelque chose alors cette valeur a un type sinon c'est None et les arguments peuvent être utilisé comme entrées dans une fonction, tout comme ils peuvent servir pour changer le comportement de la fonction**<br/>
# Maintenant, on arrive à la plus grosse question donc, sachant tout ça maintenant comment on crée des fonctions? Et bien en python il existe deux mots clés permettant de créer des fonctions et leur syntax comme tout en python est simple et direct. Nous avons d'abord la méthode la plus classique avec le **keyword def** qui est la manière conventionnelle de créer des fonctions. Pour cela il faut juste préciser le nom de la fonction après le mot clé et mettre des paranthèses dans lesquelles on peut mettre les arguments de la fonctions si elle en prend, puis on mets deux point, on indente et commence à écrire le block de code de la fonction. Par exemple voilà une fonction qui fera le traditionnel Hello world à chaque fois qu'on appelera:
# ```
# def func():
#   print("Hello world")
# ```
# Vous remarquez que avec cette méthode on peut écrire des long block de code complexe pour définir notre fonction et même inclure des bloucles et des structures conditionnelles.<br/>
# La deuxième méthode beaucoup, moins utilisée, est cela dit parfaite pour définir des fonction pouvant ténir en une ligne comme celle au dessus, en restant concis et direct. Elle est avec le mot-clé **lambda**, pour définir une fonction avec lambda il suffit de mettre les arguments de la fonction (si elle en a) séparés par des virgules, puis on mets deux points ":" et nous définissons ce que la fonction doit retourner. On peut mettre ce genre de fonction dans une variable qui leur servira de nom:
# ```
# hello = lambda : print("Hello world")
# ```

# %%
# Definis une fonction avec lambda qui retourne la racine carré d'un nombre
racine = lambda x: x**0.5

# Definir une fonction qui accueil un utilisateur en fonction de sont nom et de son sexe
def welcome(name, sexe):
  match sexe:
    case "male":
      print("Bienvenu Mr", name)
    case "female":
      print("Bienvenue Mrs", name)
    case _:
      print("Bienvenu(e) cher", name)

# %%
racine_de_quatre = racine(4)
print(racine_de_quatre)
# Out:
# 2.0

# %%
welcome(sexe="male", name="Abdou Sanogo")
# Out:
# Bienvenu Mr Abdou Sanogo

# %% [markdown]
# ## Return!
# Très généralement les fonctions retourne des valeurs, **des OBJETS**. D'ailleurs c'est cela qui est abrégé **dans la syntax de lambda, c'est comme si après les deux points on a un retour implicite**. On peut permettre à une fonction de faire un retour en utilisant le mot clé return à la fin de la fonction et je précise bien à la fin car **le return est la close de fin d'une fonction** Aucun code après un return ne sera executé, c'est la finalité des fonctions, si une fonction possède un return, elle s'arrêtera juste après avoir exécuté cette ligne

# %%
# Definissons une fonction qui peut nous dire si oui ou non un nombre donné est paire
def is_pair(nombre):
  if nombre % 2:
    # si nombre % 2 est différent de zéro cette condition sera vrai et donc on pourra en conclure que le nombre est impaire
    return False
  return True # Si le block précédent est executé celle ci ne le sera pas, donc pas vraiment besoin de faire un "else"

# %%
print(is_pair(100), type(is_pair(100)))
# Out:
# True <class 'bool'>

# %% [markdown]
# ## Les fonctions sont aussi des objets! (Reminder)
# Bien sûr puisse que tout est objet en python, les fonctions qu'on crée nous même aussi le sont, donc ils ont aussi un ID et un type

# %%
print(id(is_pair))
print(isinstance(welcome, object))
print(type(racine), type(is_pair), type(welcome))
# Out:
# 133415669656896
# True
# <class 'function'> <class 'function'> <class 'function'>

# %% [markdown]
# ## Signature d'une fonction!
# De manière simple la signature d'une est l'ensemble des détails qui lui son propre et qui permettent à l'interpreteur ainsi qu'aux programmer de la reconnaître, **son nom, le nombre d'arguments qu'elle possède, le type de ses arguments, son type de retour** constitue ce qu'on appelle la signature complète d'une fonction. Bien que python étant un langage à faible typage nous autorise à créer des fonctions avec des signature incomplète, dont les types des arguments et de retour notament seront considéré comme **"Any"** par l'interpreteur, **une signature complète apporte plus de clarté sur le rôle d'une fonction, permet de la distinguer plus facilement d'autre fonction qui pourrait avoir le même nom et permettrait aux utilisateur de savoir quel type de données doivent ils fournir pour tel et tel argument et de savoir lesquelles sont obligatoires ou optionnels**<br/>
# On va redefinir les fonctions précendente en completant leur signature

# %%
# Definir une fonction qui accueil un utilisateur en fonction de sont nom et de son sexe
def welcome(name: str, sexe: str ="male") -> None: # Avec cette nouvelle syntax on précise le type des arguments et le type de retour
  match sexe:                                      # De plus l'argument "sexe" a maintenant une valeur par défaut et devient optionnel
    case "male":
      print("Bienvenu Mr", name)
    case "female":
      print("Bienvenue Mrs", name)
    case _:
      print("Bienvenu(e) cher", name)

# Definissons une fonction qui peut nous dire si oui ou non un nombre donné est paire
def is_pair(nombre: int | float) -> bool: # Depuis la version 3.10 de python cette syntax peut être utilisé pour préciser le type d'une variable quand cette dernière peut en avoir plusieurs
  if nombre % 2:
    # si nombre % 2 est différent de zéro cette condition sera vrai et donc on pourra en conclure que le nombre est impaire
    return False
  return True # Si le block précédent est executé celle ci ne le sera pas, donc pas vraiment besoin de faire un "else"

# %%
welcome("Abdou Sanogo")
print(is_pair(34.4))
# Out:
# Bienvenu Mr Abdou Sanogo
# False

# %% [markdown]
# ## Mapping!
# Il arrive quelques fois que nous voulions appliquer la même fonction sur une collection de données sans que cette **fonction n'ait été designé pour travailler avec des collections et on ne veut naturellement pas avoir à réecrire la fonction**. On pourrait faire ça avec des boucles mais il s'avère que le code deviendrait de plus en plus complexe algorithmiquement avec ça. **C'est la qu'intervient le concept de mapping**, pour ce genre de ça python a implémenté une classe "**map**" pour ce genre de cas spécifiquement. Cette classe crée des objets maps contenant l'application de la fonction à un ensemble de données. **Let's check this out!**

# %%
carte = map(is_pair, (10, -47, -48, 50, 77, 66, 101))
print(carte) # Va afficher l'adrresse de l'objet map créer
# les maps sont des iterables pour avoir accès à leur contenu individuellement nous devons les parcourir
for resultat in carte: print(resultat, end=" ")
print() # Va à la ligne

# On peut appliquer des maps à des fonctions qui prennent plusieurs entrées, il suffit de faire autant iterables en entrées que d'arguments
# Par défaut map s'arrêtera lorsque le plus petit itérable sera satisfait
carte = map(welcome, ("Abdou", "Yacouba", "Aïcha", "Moussa"), ("male", "male", "female"))
# Pour autant la map contient bien tous les None que la fonction a retourné
for resultat in carte: print(resultat)
# Out:
# ...
# True False True True False True False
# Bienvenu Mr Abdou
# None
# Bienvenu Mr Yacouba
# None
# Bienvenue Mrs Aïcha
# None

# %% [markdown]
# ## Callable!
# Enfin on va pouvoir apporter un peu plus de clarté à ce terme dont on parle depuis le premier chapitre! **Concretement c'est quoi un callable?**, maintenant que l'on sait ce qu'est une fonction, vous allez trouvez ça tout bête mais un callable juste le terme qu'on utilise pour décrire les objets qui ne sont pas définis comme étant des fonctions mais qui peuvent se comporte comme telle. C'est par exemple le cas de toute les classes qui représente les type données en python car elle peuvent être appélé comme des fonctions pour créer des instances, c'est-à-dire des objets issue d'elle et de beaucoup d'autres d'ailleurs, **les maps y compris, la classe type etc...** Et on peut même crée nos propres classes et objets et les utiliser comme des callable, mais bon ça c'est des notions assez avancé de python qu'on verra peut être plus tard!<br/>
# La fonction "**callable**" return si oui ou non un objet précisé est un callable!

# %%
not_a_callable = "hello"
print(callable(is_pair), callable(not_a_callable), callable(int), callable(bool))
# Out:
# True False True True

# %%
true = bool(178) # Comme vous pouvez le voir les types de données qu'on a vu dans le chapitre précédent sont appelable comme des fonctions sans en être une
print(true, type(true), type(bool))
# Out:
# True <class 'bool'> <class 'type'>

# %% [markdown]
# ## Generateur!
# La grosse question: **c'est quoi un générateur?**<br/>
# Vous vous rappelez, tout à l'heure on disait que la close de fin d'une fonction c'était le **return** et donc qu'une fonction meurt après avoir fait une retour donc qu'elle ne pouvait toujours retourné qu'une seule valeur. Mais et si j'ai besoin de retourner plusieurs valeur, je fais comment?<br/>
# Et bien une première approche serait de retourner une collection dans ce cas, si vous voulez retourner plusieurs valeurs vous pouvez attendre de rassembler toutes les valeurs dans un iterable et retourner cette collection à la fin de la fonction.<br/>
# **Hourra alors, problème réglé!**<br/>
# **Enfaîte, non problème pas vraiment résolu**, maintenant supposons que pour le bon fonctionement de votre code, votre fameuse fonction doit retourner **un objet par séconde** au minimun, si vous devez fournir 10 objets et qu'il faut 50 centièmes de séconde pour preparer un seul objet, **ça fera 5 sécondes pour que votre fonction puisse retourner la collection!**.<br/>
# Donc **comment faire?** Et bien c'est à ça que servent **les Générateurs**, même si effectivement le mot clé return signifie explicitement fin de la fonction, il existe un autre mot clé permettant à une fonction de retourner un valeur et de continuer son éxécution, **le keyword yield**! C'est donc lui notre sauveur, utiliser **yield** dans une fonction transforme implicitement le type de retour de la fonction en "**Generator**" qui est un autre type d'objet python. A un niveau avancé de Python on peut utiliser plein de syntax qui crée implicitement des générateurs. Voyons voir à quoi ça ressemble tout ça!

# %%
def generate_int(range: range):
  for i in range:
    yield i
    print(i, "a été retourné!")
  print("Tous les éléments ont été retourné")

# %%
my_range = range(50, 110, 10)
generated = generate_int(my_range)
print(generated) # Affichera l'adrresse de l'objet "generator crée"
print(*generated) # Va déballer l'objet "generator" et l'afficher
# Out:
# <generator object generate_int at 0x795731274430>
# 50 a été retourné!
# 60 a été retourné!
# 70 a été retourné!
# 80 a été retourné!
# 90 a été retourné!
# 100 a été retourné!
# Tous les éléments ont été retourné
# 50 60 70 80 90 100

# %% [markdown]
# ## Python packing and unpacking method!!
# Mais quelle est donc cette **syntax bizarre** qu'on vient de faire:
# ```
# print(*generated)
# ```
# **Qu'est ce que ça peut bien signifier?**<br/>
# Ne vous inquitez pas j'ai la réponse, figurez vous que l'operateur "*" en python peut aussi être utilisé pour **emballer et déballer** des objets! Je vous explique, on avait dit tout à l'heure que **la fonction print accepte des arguments positionnel** ce qui veut dire qu'on peut lui donner autant de valeur qu'on le veut si on ne précise pas à quel arguments appartient tel valeur, elle cherchera à afficher la valeur donnée. Mais attendez **autant de valeurs qu'on veut?** Il y'a quelque chose de bizarre non? Maintenant qu'on sait définir des fonctions une des première chose qu'on remarque c'est que **une fonction à un nombre finie d'arguments**. Comment ont ils reussi un tel exploit lorsqu'ils ont crée la fonction print? Comment peut elle accepter une infinité d'arguments positionnels?<br/>
# **Well, rien de magique!** Effectivement on ne peut pas déclarer une infinité d'arguments dans la syntax d'une fonction et c'est là qu'il devient utiles **d'emballer les arguments**, c'est là que l'operateur "*" fait dans la syntax d'une fonction, lorsqu'il est utilisé dans la déclaration de la fonction il dit à l'interprêteur de rassembler toutes les valeurs (qui ne sont pas explicitement assigner à un argument particulier) données en arguments lors de l'appel de la fonction dans un iterable qu'on pourra utiliser dans la fonction **sous le nom de l'argument qui est précédé par l'asterisk**. Et lorsqu'il est utilisé dans l'appel de la fonction, il dit à l'interprêteur **de déballer un objet déballable comme un iterable ou un générateur** et d'utiliser chaque élément comme un argument positionnel! Pour mieux visualiser cet affaire bizarre, faisons un exemple avec la fonction is_pair de tout à l'heure, on va la modifier pour qu'elle puisse accepter une infinité d'arguments aussi!

# %%
def are_pair(*nombres) -> list[bool]:
    # Example de syntax qui crée un générateur implicitement
    # Cette syntax aussi appélée "list compression" va crée un générateur qui va retourner si le nombre est pair pour chaque nombre dans l'iterable "nombres"
    # Jusqu'au dernier nombre et il en fera une liste
    response = [is_pair(num) for num in nombres]
    return response

# %%
results = are_pair(1, 14, 74, 15, 81, 99, 100, 7524)
print(results)
# Ou encore
nombres = (1, 14, 74, 15, 81, 99, 100, 7524)
print(are_pair(*nombres)) # Va déballer le tuple "nombres" et utilisé chaque élément comme un argument positionnel comme en haut

# Déballage d'une liste
premier, deuxieme, troisieme, *reste = results
print(premier, deuxieme, troisieme)
print(reste)
# Out:
# [False, True, True, False, False, False, True, True]
# [False, True, True, False, False, False, True, True]
# False True True
# [False, False, False, True, True]

# %% [markdown]
# ## Variable locale et variable globale!
# Maintenant qu'on si connaît un peu en fonction, on va pouvoir expliquer le concept de variable locale et globale. Ce qu'il faut comprendre c'est que de la même manière que les variables n'ont pas de réelle identité en python, **leur existance est rélatifs au fichier ou à la fonction ou ils sont définis**.<br/>
# Je m'explique, contraitrement aux fonctions, pseudo constantes et aux classes, les variables ne peuvent pas être importé d'un module à un autre en python (On parlera de module juste après dans la prochaine session), ni d'une fonction à une autre! **Ce qui veut dire que même dans le même module, vous ne pouvez pas utiliser une variable déclarée dans une fonction si vous êtes à l'exterieur de cette dernière**. Les variables n'existent que dans la fonction ou elles sont crées.<br/>
# Dans certains cas on peut avoir besoin d'une variable pour la lire et la modifier dans une autre fonction ou dans un autre module, **c'est là que les variables globales entre en scène**. Déclarer une variable comme étant globale vous permet de la modifier dans plusieurs fonctions et modules tant que c'est derniers sont dans le même namespace. Let's check this out!

# %%
# Cette cellule va donner une erreur comme quoi: local variable 'var' referenced before assignment
var = "hello"

def func():
  print("La variable globale est: ", var)
  var = "modifié par func"
  print("Contenu de la variable globale changé!")

func()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-40-58077603cd22> in <cell line: 8>()
#       6   print("Contenu de la variable globale changé!")
#       7
# ----> 8 func()
#
# <ipython-input-40-58077603cd22> in func()
#       2 var = "hello"
#       3 def func():
# ----> 4   print("La variable globale est: ", var)
#       5   var = "modifié par func"
#       6   print("Contenu de la variable globale changé!")
#
# UnboundLocalError: local variable 'var' referenced before assignment

# %%
# Cette cellule va afficher le contenu de la variable globale "var" avant de la changer
global var_globale
var_globale = "hello"
def func():
  global var_globale
  print("La variable globale est: ", var_globale)
  var_globale = "modifié par func"
  print("Contenu de la variable globale changé!")

func()
print("Nouvelle valeur de la variable globale est: ", var_globale)
# Out:
# La variable globale est:  hello
# Contenu de la variable globale changé!
# Nouvelle valeur de la variable globale est:  modifié par func

# %% [markdown]
# ## Module!
# Nous sommes presque à la fin de ce dernier grand chapitre, maintenant on va essayer de clarifier un peu **le concept de module** dont on parle depuis un petit moment maintenant.<br/>
# La définition courte serait de dire que **tous les fichier avec l'extension ".py" sont des modules pour python** et cette définition est correcte puisque un fichier .py peut être à la fois un script et un module et qu'en programmation on veut souvent faire une différence entre ces deux là, on va un peu plus approfondir notre définition. Conventionnellement un module est un fichier qui contient du code destiné à être utilisé dans d'autre fichiers. Pour faire simple c'est un fichier .py où on est libre de définir des fonctions, des classes, des variables globale et des constantes pour les importer et les exécuter dans d'autres fichiers .py **(d'autres modules ou des scripts)**.<br/>
# Python est doté d'une panoplie de **module built-in comme math, turtle, socket, hashlib** et tellement d'autres, en tout **python a plus de 200 modules built-in** et ce qui est encore plus magnifique c'est qu'on peut **créer nos propres modules et les partager avec tous les pythonistas. Amazing, n'est ce pas?** On peut aussi **organiser un ensemble de module en package et aller jusqu'à créer des librairies**, mais bon ça c'est une autre histoire 😂<br/>
# **Dans les cellules suivante on va importer et utiliser un module qu'on a crée nous même et stocker dans le dossier partagé drive!**

# %%
# C'est deux ligne ont été généré par Colab AI et permettront de mounter votre google drive au filesystem de ce colab
# Exécuter cette cellule vous demandera de vous connecter à votre google drive!

# prompt: generate the code to mount my google drive!
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# Cette ligne permettra de copier le module dans le repertoire courant "/content". Parce qu'on doit s'assurer que le module soit dans le même dossier que le fichier ou on veut l'importer
# Notez que le chemin du fichier "module.py" peut être différent dans votre drive, pensez à verifier l'emplacement du dossier partagé SanogoPython dans votre google drive!
# !cp drive/MyDrive/Colab\ Notebooks/Intro2Python/module.py .
# !ls -F
# Out:
# drive/	module.py  sample_data/

# %%
# Ce module contient les deux fonctions is_pair et are_pair des cellules précedente ainsi qu'une variable globale appélée "var"
# Pour utiliser les objets dans ce module on peut les importer individuellement avec la syntax from module import ... comme cela
from module import var
print("La variable globale dans le module 'module' a pour valeur: ", var)
# Ou tout importer avec: from module import *
# Out:
# La variable globale dans le module 'module' a pour valeur:  hello

# %%
# Ou on peut aussi importer le module lui même et acceder aux objets à l'interieur en utilisant la syntax "nom_du_module.objet"
import module
print(module.is_pair(77))
print(module.are_pair(77, 84, 25, 17, 5))
# Out:
# False
# [False, True, False, False, False]

# %% [markdown]
# ## Tracebacks!
# On est arrivé à la dernière partie de ce notebook et non la moins importante, **les tracebacks**. Basiquement un **traceback** c'est ce qui nous permet de savoir qu'est qui ne va pas dans notre code pour pouvoir le debugger et comme tout se passe rarement comme sur des roulettes quand on code, il est essentiel voir vitale de pouvoir lire et comprendre un traceback.<br/>
# Chaque traceback Python comporte plusieurs sections importantes. Le diagramme ci-dessous est une tentative pour vous aider à voir et comprendre ces différentes parties.<br/>
#
# ![python-traceback](https://drive.google.com/uc?export=view&id=1MfI_uw56UCWfRS4zTIaZyrRw-wTkJt8H)
#
# En python, il est préférable de lire le traçage de bas en haut. La dernière ligne du traçage, la ligne du message d'erreur, contient le nom de l'exception qui a été déclenchée (entourée en bleu). À côté du nom de l'exception se trouve le message d'erreur (encadré en vert). Ce message contient généralement des informations utiles pour comprendre la raison de l'exception levée. En remontant dans le traçage (encadrés en jaune), les différents appels de fonction de bas en haut, du plus récent au moins récent. Ces appels sont représentés par deux entrées de ligne pour chaque appel. La première ligne de chaque appel contient des informations telles que: le chemin absolu du fichier ou du module python, le numéro de ligne exact (la ligne qui a provoqué l'exception) et le nom de la fonction, le tout spécifiant où se trouve le code. La deuxième ligne contient le code réellement exécuté (souligné en rouge).<br/>
# Par exemple dans cet image, on a un **"NameError"** qui arrive lorsqu'on essaie d'utiliser une variable qui n'a pas été définie! C'est parce qu'il y'avait un typo dans ce code, le nom de la variable c'était **"someone" et non "someon"**. Vous l'aurez compris les tracebacks c'est extrêment important de pouvoir les lire et les comprendre, parce que quand on travaille sur des projets importants on aura forcément beaucoup d'erreurs et si on sait interprêter les tracebacks on peut les résoudre!

# %% [markdown]
# ## Homework1!
# Réécrire le homework1 du tout premier notebooks, en utilisant une boucle pour vous assurez que l'utilisateur donnera un nombre différent de zéro comme valeur de "a" dans l'équation ax² + bx + c et en utilisant le module math pour faire le racine carré de delta!

# %%
# Votre code ici!

# %% [markdown]
# ## Homework2!
# Apprendre à faire un dessin avec le module turtle! Faire un fichier .py qui lorsqu'il est exécuté dessine l'objet de votre choix.

# %% [markdown]
# ## Homework3!
# Ecrire un petit module de calcul, définissez vos fonctions pour faire **des calculs comme la racine, le factoriel, calculer un certain terme de la suite de fibonacci ou utilisé le théorème de pythagore pour calculer un coté d'un triangle connaissant la longueur des deux autres!** Définissez autant de fonctions que vous voulez dans votre module puis importez les et testez les dans un autres fichier ou notebook!
